# %% [markdown]
# **Git/GitHub**<br><br><br>

# %% [markdown]
# **Контроль версий**: хранятся все версии редактируемых документов, и можно вернуться к любой сохраненной версии в любой момент времени.

# %% [markdown]
# ####**Централизация - децентрализация**<br><br><br>

# %% [markdown]
# ![2022-11-23_17-08-32.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# <br>**Более детально:**

# %% [markdown]
# ![68747470733a2f2f692e726564642e69742f6e6d317730676e66327a6831312e706e67.png](data:image/png;base64,...)

# %% [markdown]
# ###**Workflow - команды**

# %% [markdown]
# **Копирование репозитория для создания связи между сервером GitHub (известрым Git как origin) и вашей локальной системой:**

# %%
git clone https://{git_token}@github.com/{username}/{repository}

# %% [markdown]
# здесь:
#
#
# *   username = AndreoBochelli
# *   reppository = DS2023
# *   git_token = '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'

# %% [markdown]
# итак:

# %%
# !git clone https://'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'@github.com/AndreoBochelli/DSclass2023

# %% [markdown]
# ####**Добавление своих изменений в глобальный репозиторий***<br>

# %% [markdown]
# В локальном репозитарии создаём свой личный каталог:

# %%
# %mkdir VasyaPupkin

# %%
# !git status

# %%
# !git add .

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# Статус изменился.

# %% [markdown]
# ![2022-11-26_19-15-47.png](data:image/png;base64,...)

# %%
git commit -m 'Initial commit оf Vasya'

# %% [markdown]
# ![2022-11-27_0-36-40.png](data:image/png;base64,...)

# %% [markdown]
# Синхронизация с глобальным репозиторием:

# %%
# !git push origin main

# %% [markdown]
# ![2022-11-27_0-43-13.png](data:image/png;base64,...)

# %% [markdown]
# Обратный процесс: передача ВСЕХ изменений из глобального репозитория в локальный

# %%
# !git pull --all

# %% [markdown]
# ![2022-11-27_13-24-57.png](data:image/png;base64,...)

# %% [markdown]
# ##***Branching***<br>

# %% [markdown]
# Добавьте свои изменения в master branch, когда они созреют

# %% [markdown]
# ![2022-11-28_1-13-17.png](data:image/png;base64,...)

# %% [markdown]
# <br>
# <H3>Создаём новую ветку</H3>

# %%
# !git branch future-plans

# %% [markdown]
# ![2022-11-29_3-49-32.png](data:image/png;base64,...)

# %% [markdown]
# <br>
# <H3>Переключаемся на неё:</H3>

# %%
# !git checkout future-plans

# %% [markdown]
# ![2022-11-29_3-53-07.png](data:image/png;base64,...)

# %% [markdown]
# <br>
# <H3>Вносим локальные изменения. Перед выносом  изменений на сцену убеждаемя, что мы действительно в новой ветке:</h3>

# %%
# !git status

# %% [markdown]
# On branch future-plans<br>
# Changes not staged for commit:<br>
#  (use "git add <file>..." to update what will be committed)<br>
#  (use "git checkout -- <file>..." to discard changes in working <br>directory)
#    modified: stationlocations<br>
# no changes added to commit (use "git add" and/or "git commit -a")

# %%
# !git add one_of_files
# !git  commit one_of_files -m 'making a change in a branch'

# %% [markdown]
# ![2022-11-29_3-54-04.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git status

# %% [markdown]
# On branch future-plans.......

# %% [markdown]
# <H3>Обратно в главную ветку!</H3>

# %%
# !git checkout main

# %%
# !git merge future-plans

# %% [markdown]
# <H3>Сливаем в неё сделанные изменения...</H3>

# %%
# !git merge future-plans

# %% [markdown]
# <H3>...и уничтожаем более ненужную ветвь</H3>

# %%
git branch -d future-plans

# %% [markdown]
# <H3>Пока мы на 1 коммит впереди Main branch...</H3>

# %% [markdown]
# ![2022-11-29_3-55-19.png](data:image/png;base64,...)

# %%
# !git push origin main

# %% [markdown]
# <H3>... теперь синхронны:</H3>

# %% [markdown]
# ![2022-11-29_4-57-20.png](data:image/png;base64,...)

# %% [markdown]
# ### *Ветвление - Разрешение конфликтов*

# %% [markdown]
# ![2022-11-29_6-03-31.png](data:image/png;base64,...)

# %%
# Start a new feature AND JUST switch ti it!
# !git checkout -b new-feature main
# Edit some files
# !git add <file>
# !git commit -m "Start a feature"
# Edit some files
# !!git add <file>
git commit -m "Finish a feature"
# Merge in the new-feature branch
# !git checkout main
# !git merge new-feature
# !git branch -d new-feature

# %% [markdown]
# ![2022-11-29_6-04-59.png](data:image/png;base64,...)

# %%
#Start a new feature
# !git checkout -b new-feature main
# Edit some files
# !git add <file>
# !git commit -m "Start a feature"
# Edit some files
# !git add <file>
# !git commit -m "Finish a feature"
# Develop the main branch
# !git checkout main
# Edit some files
# !git add <file>
# !git commit -m "Make some super-stable changes to main"
# Merge in the new-feature branch
# !git merge new-feature
# !git branch -d new-feature

# %% [markdown]
# **<H3>3-way merge</H3>** может вызвать конфликт:

# %% [markdown]
# ```
# here is some content not affected by the conflict
# <<<<<<< main
# this is conflicted text from main
# =======
# this is conflicted text from feature branch
# >>>>>>> feature branch;
# ```

# %% [markdown]
# ##***GitFlow***<br>

# %% [markdown]
# https://danielkummer.github.io/git-flow-cheatsheet/index.ru_RU.html
# <br><br><br><br>

# %% [markdown]
# ![2022-11-30_0-19-41.png](data:image/png;base64,...)

# %% [markdown]
# <br><br>
# [The easiest explanation of using GitFlow](https://www.youtube.com/watch?v=9SrL5Ut5LLw/)<br><br>
# <br><br>

# %% [markdown]
# ***К домашнему заданию***
# <br>
# [Книга по Git (с инструкциями по локальной установке)](https://git-scm.com/book/en/v2/Getting-Started-Installing-Git)

# %% [markdown]
# # *Дополнительное чтение*

# %% [markdown]
# *   [Git Rebase: руководство по использованию](https://habr.com/ru/post/161009/)
# *   [Git FAQ](https://www.git-tower.com/learn/git/faq/restore-repo-to-previous-revision)
# *   [Тонкости благополучного git-merge](https://habr.com/ru/post/195674/)
